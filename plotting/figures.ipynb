# %% [markdown]
# # Figures

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import numpy as np

#%matplotlib inline

sns.set(font_scale = 1.3, style="whitegrid")
sns.set_style("whitegrid", {'axes.edgecolor' : '.0001'})

def pos_to_char(pos):
    return chr(pos + 65)

# %%
from copy import  deepcopy
path = "../src/simulations/"

# %%
fig, axs = plt.subplots(2, 3, figsize=(18, 9), sharey=False)

colors = "black"
color = "black"
linewidth = 2
population_size = 1000


# all simulation files for probability and no alpha adapted selection
files = os.listdir("../src/simulations/")
files = ["../src/simulations/" + file for file in files if "probability" in file and "adapted" not in file]

# filter the probabilities
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

# filter for constant
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 



# all simulation files for probability and no alpha adapted selection
files = os.listdir("../src/simulations/")
files = ["../src/simulations/" + file for file in files if "probability" in file and "adapted" not in file]

# filter the probabilities
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

# filter for constant
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist()

# %%
tmp = viability_constant_df[viability_constant_df["population_size"] == 5000]
tmp = tmp[tmp["parameter"] == 1.1]
tmp[tmp["selection_coefficient"] == 0]
# Out:
#     level_0  index  fixation_probability  parameter  population_size  \
# 11      125      0              0.000186        1.1             5000
#
#    population_size_model  selection_coefficient  selection_coefficient2  \
# 11              constant                    0.0                     NaN
#
#         selection_type  selection_period
# 11  viability_constant           0.06283

# %%
tmp = fecundity_constant_df[fecundity_constant_df["population_size"] == 5000]
tmp = tmp[tmp["parameter"] == 1.1]
tmp[tmp["selection_coefficient"] == 0]
# Out:
#     level_0  index  fixation_probability  parameter  population_size  \
# 30      121      0              0.000222        1.1             5000
#
#    population_size_model  selection_coefficient  selection_coefficient2  \
# 30              constant                    0.0                     NaN
#
#         selection_type  selection_period
# 30  fecundity_constant           0.06283

# %%
tmp = viability_constant_df[viability_constant_df["population_size"] == 1000]
tmp = tmp[tmp["parameter"] == 1.1]
tmp[tmp["selection_coefficient"] == 0]
# Out:
#    level_0  index  fixation_probability  parameter  population_size  \
# 1       28      0              0.000922        1.1             1000
#
#   population_size_model  selection_coefficient      selection_type  \
# 1              constant                    0.0  viability_constant
#
#    selection_coefficient2  selection_period
# 1                     NaN               NaN

# %%
tmp = viability_constant_df[viability_constant_df["population_size"] == 1000]
tmp = tmp[tmp["parameter"] == 2]
tmp[tmp["selection_coefficient"] == 0]
# Out:
#    level_0  index  fixation_probability  parameter  population_size  \
# 5       37      0              0.000178        2.0             1000
#
#   population_size_model  selection_coefficient      selection_type  \
# 5              constant                    0.0  viability_constant
#
#    selection_coefficient2  selection_period
# 5                     NaN               NaN

# %%
tmp = fecundity_constant_df[fecundity_constant_df["population_size"] == 1000]
tmp = tmp[tmp["parameter"] == 1.1]
tmp[tmp["selection_coefficient"] == 0]
# Out:
#    level_0  index  fixation_probability  parameter  population_size  \
# 6       43      0              0.000932        1.1             1000
#
#   population_size_model  selection_coefficient      selection_type  \
# 6              constant                    0.0  fecundity_constant
#
#    selection_coefficient2  selection_period
# 6                     NaN               NaN

# %%
tmp = fecundity_constant_df[fecundity_constant_df["population_size"] == 1000]
tmp = tmp[tmp["parameter"] == 2]
tmp[tmp["selection_coefficient"] == 0]
# Out:
#     level_0  index  fixation_probability  parameter  population_size  \
# 23      196      0              0.000246        2.0             1000
#
#    population_size_model  selection_coefficient      selection_type  \
# 23              constant                    0.0  fecundity_constant
#
#     selection_coefficient2  selection_period
# 23                     NaN               NaN

# %%
(0.000178 + 0.000246) / 2
# Out:
# 0.000212

# %%
1/(1000)
# Out:
# 0.001

# %%
(0.000932 + 0.000922) / 2
# Out:
# 0.000927

# %% [markdown]
# ## Figure 3

# %%
# %matplotlib inline

# %%
path = "../src/simulations/"
colors = "black"
color = "black"
linewidth = 2
population_size = 1000


# all simulation files for probability and no alpha adapted selection
files = os.listdir(path)
files = [path + file for file in files if "probability" in file and "adapted" not in file]

# filter the probabilities
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

# %%
fig, axs = plt.subplots(2, 3, figsize=(18, 9), sharey=False)

colors = "black"
color = "black"
linewidth = 2
population_size = 1000


# all simulation files for probability and no alpha adapted selection
files = os.listdir(path)
files = [path + file for file in files if "probability" in file and "adapted" not in file]

# filter the probabilities
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

# filter for constant
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 



# all simulation files for probability and no alpha adapted selection
files = os.listdir(path)
files = [path + file for file in files if "probability" in file and "adapted" not in file]

# filter the probabilities
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

# filter for constant
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 


# viability selection constant N=1000
ax = axs[0][0]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
                palette=colors, s=40, legend=False,  color = color).set_title("a) viability selection (N=" + str(population_size) + ")",  loc="left")



ins = axs[0][0].inset_axes([0.2, 0.67, 0.25, 0.25])
sns.lineplot(data=viability_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
             palette=colors, linewidth=linewidth, legend=False,  color = color)

ins.set_yscale("log")
ins.set(ylim=(0.00001, 0.1), xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.patch.set_linewidth(2)
ins.tick_params(bottom=True, top=False, left=True, right=True)

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
#ax.grid(True)
ax.patch.set_linewidth(2)
ax.set(xlabel='', ylabel='fixation probability')





#
# fedundity selection constant N=1000
ax = axs[1][0]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]

sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)

sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("d) fecundity selection (N=" + str(population_size) + ")", loc="left")


ins = axs[1][0].inset_axes([0.2, 0.67, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
             palette=colors, linewidth=linewidth, legend=False,  color = color)

ins.set_yscale("log")
ins.set(ylim=(0.00001, 0.1), xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.tick_params(bottom=True, top=False, left=True, right=True)
ins.patch.set_linewidth(2)

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.grid(True)
ax.patch.set_linewidth(2)
ax.set(xlabel='α', ylabel='fixation probability')




## fixation times

files = os.listdir(path)
files = [path + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and "adapted" not in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 


# viability selection constant N=1000

ax = axs[0][1]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("b) viability selection (N=" + str(population_size) + ")",  loc="left")
#
for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = viability_constant_population_size[viability_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)



ins = axs[0][1].inset_axes([0.25, 0.67, 0.25, 0.25])
sns.lineplot(data=viability_constant_population_size,x="parameter", y="fixation_time", style="selection_coefficient", ax=ins, linewidth=2, legend=False, color = color)
ins.set_yscale("log")
ins.set(xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.patch.set_linewidth(2)
ins.tick_params(bottom=True, top=False, left=True, right=True)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
ax.grid(True)
ax.set(xlabel='', ylabel='fixation time')


# fedundity selection constant N=1000
ax = axs[1][1]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)

legend_pos=-0.25
ncol=3
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol) #labels=["s=0","s=0.01","s=0.1"]
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            

#
for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("e) fecundity selection (N=" + str(population_size) + ")", loc="left")

ins = axs[1][1].inset_axes([0.25, 0.67, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_time", style="selection_coefficient", ax=ins, linewidth=2, legend=False, color = color)
ins.set_yscale("log")
ins.set(xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.patch.set_linewidth(2)
ins.tick_params(bottom=True, top=False, left=True, right=True)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
ax.grid(True)
ax.set(xlabel='α', ylabel='fixation time')



# difference in fixation probabilities
files = os.listdir(path)
files = [path + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and "adapted" not in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
fecundity_constant = df[df["selection_type"] == "fecundity_constant"]
viability_constant = df[df["selection_type"] == "viability_constant"]

selection_coefficients = [0, 0.01, 0.1]
population_sizes = [1000]

difference_frame = []
for selection_coefficient in selection_coefficients:
    constant = pd.concat([fecundity_constant, viability_constant]).reset_index()
    constant = constant[constant["population_size"] == population_size]
    constant = constant[constant["selection_coefficient"] == selection_coefficient]
    for alpha in [1.1, 1.3, 1.5, 1.7, 1.9, 2.0]:
        try:
            alpha_frame = constant[constant["parameter"] == alpha]
            fc = alpha_frame[alpha_frame["selection_type"] == "fecundity_constant"]
            vc = alpha_frame[alpha_frame["selection_type"] == "viability_constant"]
            diff = fc.fixation_probability.item() - vc.fixation_probability.item()
            #diff_std = np.mean([fc.standard_deviation.item(), vc.standard_deviation.item()])
            #print(alpha, diff, population_size, selection_coefficient)

            difference_frame.append([alpha, diff, population_size, selection_coefficient])
        except Exception as e:
            print(e, population_size, selection_coefficient, alpha)
difference_frame = pd.DataFrame(difference_frame, columns=["alpha", "fecundity-viability", "population_size", "selection_coefficient"])

ax = axs[0][2]
population_size = 1000
difference_frame_population__size = difference_frame[difference_frame["population_size"] == population_size]
sns.lineplot(data=difference_frame_population__size, x="alpha", y="fecundity-viability",linewidth=2, style="selection_coefficient", ax=ax, color=colors, legend=False)
sns.scatterplot(data=difference_frame_population__size, x="alpha", y="fecundity-viability",
                s=40, hue="selection_coefficient", ax=ax, legend=False, color=color).set_title("c) fecundity-viability selection (N=" + str(population_size) + ")", loc="left")
ax.set(xlabel='α', ylabel='fixation probability difference')
ax.grid(True)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
ax.set_ylim(-0.003, 0.0015)



files = os.listdir(path)
files = [path + file for file in files]
# filter the timess
df_time = [pd.read_csv(file) for file in files if "time" in file and "adapted" not in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
fecundity_constant = df[df["selection_type"] == "fecundity_constant"]
viability_constant = df[df["selection_type"] == "viability_constant"]

selection_coefficients = [0, 0.01, 0.1]
difference_frame = []
for selection_coefficient in selection_coefficients:

    constant = pd.concat([fecundity_constant, viability_constant]).reset_index()
    constant = constant[constant["population_size"] == population_size]
    constant = constant[constant["selection_coefficient"] == selection_coefficient]

    for alpha in [1.1, 1.3, 1.5, 1.7, 1.9, 2.0]:
        try:
            alpha_frame = constant[constant["parameter"] == alpha]
            fc = alpha_frame[alpha_frame["selection_type"] == "fecundity_constant"]
            vc = alpha_frame[alpha_frame["selection_type"] == "viability_constant"]
            diff = fc.fixation_time.item() - vc.fixation_time.item()
            diff_std = np.mean([fc.standard_deviation.item(), vc.standard_deviation.item()])
            #print(alpha, diff, population_size, selection_coefficient)

            difference_frame.append([alpha, diff, population_size, selection_coefficient, diff_std])
        except:
            print(population_size, selection_coefficient, alpha)
            
difference_frame = pd.DataFrame(difference_frame, columns=["alpha", "fecundity-viability", "population_size", "selection_coefficient", "standard_deviation"])
difference_frame_population__size = difference_frame[difference_frame["population_size"] == population_size]
ax = axs[1][2]
sns.lineplot(data=difference_frame_population__size, x="alpha", y="fecundity-viability",linewidth=2, style="selection_coefficient", ax=ax, color=color, legend=False)
sns.scatterplot(data=difference_frame_population__size, x="alpha", y="fecundity-viability",
                s=40, style="selection_coefficient", ax=ax,  legend=False, color=color).set_title("f) fecundity-viability selection (N=" + str(population_size) + ")", loc="left")
ax.set(xlabel='α', ylabel='fixation time difference')
ax.grid(True)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
#ax.set_ylim(-300, 50)



plt.tight_layout()
#plt.savefig("./figures/figure_3.pdf", dpi=500)
# Out:
# /tmp/ipykernel_997723/792295882.py:43: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
# /tmp/ipykernel_997723/792295882.py:45: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
# /tmp/ipykernel_997723/792295882.py:51: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=viability_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
# /tmp/ipykernel_997723/792295882.py:75: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
# /tmp/ipykernel_997723/792295882.py:78: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("d) fecundity selection (N=" + str(population_size) + ")", loc="left")
# /tmp/ipykernel_997723/792295882.py:82: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,

# %% [markdown]
# ## Figure 4

# %%
from copy import deepcopy
import string

# %%
alphas = [1.1, 1.3, 1.5, 1.7, 1.9, 2.0]
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "probability" in file and "adapted" not in file]
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

fig, axs = plt.subplots(1, 2, figsize=(18, 9), sharey=False)

i = 0
population_size = 1000
color = "black"
viability_constant_population_size = viability_constant_df[viability_constant_df["population_size"] == population_size]
fecundity_constant_population_size = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]

viability_constant_population_size = viability_constant_population_size.drop(labels=["level_0"], axis=1)
viability_constant_population_size = viability_constant_population_size.sort_values(by="parameter")


fecundity_constant_population_size = fecundity_constant_population_size.drop(labels=["level_0"], axis=1)
fecundity_constant_population_size = fecundity_constant_population_size.sort_values(by="parameter")

neutral = viability_constant_population_size[viability_constant_population_size.selection_coefficient == 0]
via_001 = viability_constant_population_size[viability_constant_population_size.selection_coefficient == 0.01]
via_01 = viability_constant_population_size[viability_constant_population_size.selection_coefficient == 0.1]
neutral.reset_index(drop=True, inplace=True)
via_001.reset_index(drop=True, inplace=True)
via_01.reset_index(drop=True, inplace=True)

effect_via_01 = via_01.fixation_probability - neutral.fixation_probability
effect_via_001 = via_001.fixation_probability - neutral.fixation_probability
neutral_via = neutral.fixation_probability

neutral = fecundity_constant_population_size[fecundity_constant_population_size.selection_coefficient == 0]
fec_001 = fecundity_constant_population_size[fecundity_constant_population_size.selection_coefficient == 0.01]
fec_01 = fecundity_constant_population_size[fecundity_constant_population_size.selection_coefficient == 0.1]
neutral.reset_index(drop=True, inplace=True)
fec_001.reset_index(drop=True, inplace=True)
fec_01.reset_index(drop=True, inplace=True)

effect_fec_01 = fec_01.fixation_probability - neutral.fixation_probability
effect_fec_001 = fec_001.fixation_probability - neutral.fixation_probability
neutral_fec = neutral.fixation_probability
neutral = neutral_fec

colors = "blue"
color = "blue"
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "probability" in file and "both" in file]
# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]

df = df[df["population_size"] == population_size]
df_viability_01 = df[df["selection_coefficient"] == 0.1].reset_index()
df_viability_001 = df[df["selection_coefficient"] == 0.01].reset_index()
df_fecundity_01 = df[df["selection_coefficient2"] == 0.1].reset_index()
df_fecundity_001 = df[df["selection_coefficient2"] == 0.01].reset_index()

df = df.sort_values(by="parameter")

via_01_fec = deepcopy(df[df.selection_coefficient == 0.1])
via_001_fec = deepcopy(df[df.selection_coefficient == 0.01])

via_01_fec001 = via_01_fec[via_01_fec.selection_coefficient2 == 0.01]
via_01_fec01 = via_01_fec[via_01_fec.selection_coefficient2 == 0.1]

via_001_fec001 = via_001_fec[via_001_fec.selection_coefficient2 == 0.01]
via_001_fec01 = via_001_fec[via_001_fec.selection_coefficient2 == 0.1]

via_01_fec001 = via_01_fec001.fixation_probability
via_01_fec01 = via_01_fec01.fixation_probability
via_001_fec001 = via_001_fec001.fixation_probability
via_001_fec01 = via_001_fec01.fixation_probability


ax = axs[i]

set_label = False
if i == 0:
    set_label = True
else:
    set_label = False


sns.lineplot(x=alphas, y=neutral, label="neutral", linestyle='-', color="grey", alpha=0.75, ax=ax, legend=False)

sns.lineplot(x=alphas, y=neutral 
             + effect_fec_001 
             + effect_via_01, 
             label=r"neutral+effect $fecundity_{s=0.01}$+effect $viability_{s=0.1}$", linestyle='-.', color="black", ax=ax, legend=False)
sns.lineplot(x=alphas, y=via_01_fec001, 
             label="$viability_{s=0.1}$ $fecundity_{s=0.01}$", linestyle='-.', color="blue", ax=ax, legend=False)

sns.lineplot(x=alphas, y=neutral 
             + effect_fec_01 
             + effect_via_001, 
             label=r"neutral+effect $fecundity_{s=0.1}$+effect $viability_{s=0.01}$", linestyle='--', color="black", ax=ax, legend=False)
sns.lineplot(x=alphas, y=via_001_fec01, 
             label="$viability_{s=0.01}$ $fecundity_{s=0.1}$", linestyle='--', color="blue", ax=ax, legend=False)

sns.lineplot(x=alphas, y=neutral 
             + effect_fec_001 
             + effect_via_001, 
             label=r"neutral+effect $fecundity_{s=0.01}$+effect $viability_{s=0.01}$", linestyle=':', color="black", ax=ax,legend=False)
sns.lineplot(x=alphas, y=via_001_fec001, 
             label="$viability_{s=0.01}$ $fecundity_{s=0.01}$", linestyle=':', color="blue", ax=ax,legend=False)

sns.lineplot(x=alphas, y=neutral 
             + effect_fec_01 
             + effect_via_01, 
             label=r"neutral+effect $fecundity_{s=0.1}$+effect $viability_{s=0.1}$", linestyle='-', color="black", ax=ax,legend=False)
sns.lineplot(x=alphas, y=via_01_fec01, 
             label=r"$viability_{s=0.1}$ $fecundity_{s=0.1}$", linestyle='-', color="blue", ax=ax,legend=False).set_title("a) viability + fecundity selection (N=" + str(population_size) + ")", loc="left")

ax.set(xlabel='α', ylabel='fixation probability')


legend_pos=-0.15
ncol=1
box = ax.get_position()
if set_label:
    h, l = ax.get_legend_handles_labels()
    leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, title='')




        
        
        
alphas = [1.1, 1.3, 1.5, 1.7, 1.9, 2.0]
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "time" in file and "adapted" not in file]
df_time = [pd.read_csv(file) for file in files if "time" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

i = 1
population_size = 1000
color = "black"
viability_constant_population_size = viability_constant_df[viability_constant_df["population_size"] == population_size]
fecundity_constant_population_size = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]

viability_constant_population_size = viability_constant_population_size.drop(labels=["level_0"], axis=1)
viability_constant_population_size = viability_constant_population_size.sort_values(by="parameter")

fecundity_constant_population_size = fecundity_constant_population_size.drop(labels=["level_0"], axis=1)
fecundity_constant_population_size = fecundity_constant_population_size.sort_values(by="parameter")

neutral = viability_constant_population_size[viability_constant_population_size.selection_coefficient == 0]
via_001 = viability_constant_population_size[viability_constant_population_size.selection_coefficient == 0.01]
via_01 = viability_constant_population_size[viability_constant_population_size.selection_coefficient == 0.1]
neutral.reset_index(drop=True, inplace=True)
via_001.reset_index(drop=True, inplace=True)
via_01.reset_index(drop=True, inplace=True)

effect_via_01 = via_01.fixation_time - neutral.fixation_time
effect_via_001 = via_001.fixation_time - neutral.fixation_time
neutral_via = neutral.fixation_time

neutral = fecundity_constant_population_size[fecundity_constant_population_size.selection_coefficient == 0]
fec_001 = fecundity_constant_population_size[fecundity_constant_population_size.selection_coefficient == 0.01]
fec_01 = fecundity_constant_population_size[fecundity_constant_population_size.selection_coefficient == 0.1]
neutral.reset_index(drop=True, inplace=True)
fec_001.reset_index(drop=True, inplace=True)
fec_01.reset_index(drop=True, inplace=True)

effect_fec_01 = fec_01.fixation_time - neutral.fixation_time
effect_fec_001 = fec_001.fixation_time - neutral.fixation_time
neutral_fec = neutral.fixation_time
neutral = neutral_fec

colors = "blue"
color = "blue"
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "time" in file and "both" in file]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]

df = df[df["population_size"] == population_size]
df_viability_01 = df[df["selection_coefficient"] == 0.1].reset_index()
df_viability_001 = df[df["selection_coefficient"] == 0.01].reset_index()
df_fecundity_01 = df[df["selection_coefficient2"] == 0.1].reset_index()
df_fecundity_001 = df[df["selection_coefficient2"] == 0.01].reset_index()

df = df.sort_values(by="parameter")

via_01_fec = deepcopy(df[df.selection_coefficient == 0.1])
via_001_fec = deepcopy(df[df.selection_coefficient == 0.01])

via_01_fec001 = via_01_fec[via_01_fec.selection_coefficient2 == 0.01]
via_01_fec01 = via_01_fec[via_01_fec.selection_coefficient2 == 0.1]

via_001_fec001 = via_001_fec[via_001_fec.selection_coefficient2 == 0.01]
via_001_fec01 = via_001_fec[via_001_fec.selection_coefficient2 == 0.1]

via_01_fec001 = via_01_fec001.fixation_time
via_01_fec01 = via_01_fec01.fixation_time
via_001_fec001 = via_001_fec001.fixation_time
via_001_fec01 = via_001_fec01.fixation_time


ax = axs[i]

set_label = False
if i == 1:
    set_label = True
else:
    set_label = False


sns.lineplot(x=alphas, y=neutral, label="neutral", linestyle='-', color="grey", alpha=0.75, ax=ax, legend=False)

sns.lineplot(x=alphas, y=neutral 
             + effect_fec_001 
             + effect_via_01, 
             label=r"neutral+effect $fecundity_{s=0.01}$+effect $viability_{s=0.1}$", linestyle='-.', color="black", ax=ax, legend=False)
sns.lineplot(x=alphas, y=via_01_fec001, 
             label="$viability_{s=0.1}$ $fecundity_{s=0.01}$", linestyle='-.', color="blue", ax=ax, legend=False)

sns.lineplot(x=alphas, y=neutral 
             + effect_fec_01 
             + effect_via_001, 
             label=r"neutral+effect $fecundity_{s=0.1}$+effect $viability_{s=0.01}$", linestyle='--', color="black", ax=ax, legend=False)
sns.lineplot(x=alphas, y=via_001_fec01, 
             label="$viability_{s=0.01}$ $fecundity_{s=0.1}$", linestyle='--', color="blue", ax=ax, legend=False)


sns.lineplot(x=alphas, y=neutral 
             + effect_fec_001 
             + effect_via_001, 
             label=r"neutral+effect $fecundity_{s=0.01}$+effect $viability_{s=0.01}$", linestyle=':', color="black", ax=ax,legend=False)

#    try:
sns.lineplot(x=alphas, y=via_001_fec001, 
             label="$viability_{s=0.01}$ $fecundity_{s=0.01}$", linestyle=':', color="blue", ax=ax,legend=False)
#    except:
#        sns.lineplot(x=alphas[:-1], y=via_001_fec001, 
#                     label="$viability_{s=0.01}$ $fecundity_{s=0.01}$", linestyle=':', color="blue", ax=ax,legend=False)

sns.lineplot(x=alphas, y=neutral 
             + effect_fec_01 
             + effect_via_01, 
             label=r"neutral+effect $fecundity_{s=0.1}$+effect $viability_{s=0.1}$", linestyle='-', color="black", ax=ax,legend=False)
sns.lineplot(x=alphas, y=via_01_fec01, 
             label=r"$viability_{s=0.1}$ $fecundity_{s=0.1}$", linestyle='-', color="blue", ax=ax,legend=False).set_title("b) viability + fecundity selection (N=" + str(population_size) + ")", loc="left")

ax.set(xlabel='α', ylabel='fixation time')


legend_pos=-0.15
ncol=1
box = ax.get_position()
if set_label:
    h, l = ax.get_legend_handles_labels()
    leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, title='')

plt.tight_layout()
plt.savefig("./figures/figure_4.pdf", dpi=500)

# %% [markdown]
# ## Figure 5

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 6), sharey=False)
    
    
files = os.listdir(path)
files = [path + file for file in files if "probability" in file and "adapted" not in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
fecundity_constant_df["adapted_alpha"] = False
fecundity_constant_df_non_adapted_alpha = deepcopy(fecundity_constant_df)


files = os.listdir(path)
files = [path + file for file in files if "adapted" in file and "probability" in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()

fecundity_constant_df_adapted_alpha = deepcopy(fecundity_constant_df)
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist()     

    
i = 0
population_size = 1000
fecundity_constant_df = deepcopy(fecundity_constant_df_non_adapted_alpha)
colors = "black"
color = "black"
linewidth = 2
ax = axs[i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]

sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("a) fecundity selection (N=" + str(population_size) + ")", loc="left")

ins = axs[i].inset_axes([0.65, 0.3, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
             palette=colors, linewidth=linewidth, legend=False,  color = color)

    
    
    
fecundity_constant_df = deepcopy(fecundity_constant_df_adapted_alpha)
colors = "blue"
color = "blue"
linewidth = 2
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=True,  color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient",
                ax=ax, palette=colors, s=40, color = color, legend=False).set_title("a) fecundity selection (N=" + str(population_size) + ")", loc="left")
#ins = axs[i].inset_axes([0.65, 0.25, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
ins.set_yscale("log")
ins.set(ylim=(0.00001, 1), xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.tick_params(bottom=True, top=False, left=True, right=True)
ins.patch.set_linewidth(2)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.grid(True)
ax.patch.set_linewidth(2)
ax.set(xlabel='αₐ', ylabel='fixation probability')
    
    
legend_pos=-0.25    
ncol=3
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            
        
        

        
# fixation times
files = os.listdir(path)
files = [path + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and "adapted" not in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

fecundity_constant_df["adapted_alpha"] = False
fecundity_constant_df_non_adapted_alpha = deepcopy(fecundity_constant_df)

files = os.listdir(path)
files = [path + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "adapted" in file and "time" in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

fecundity_constant_df_adapted_alpha = deepcopy(fecundity_constant_df)        
        


i = 1
population_size = 1000
fecundity_constant_df = deepcopy(fecundity_constant_df_non_adapted_alpha)

colors = ["#03045e", "#0077b6", "#00b4d8"]
colors = "black"
color = "black"
linewidth = 2

ax = axs[i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("b) fecundity selection (N=" + str(population_size) + ")", loc="left")

ins = axs[i].inset_axes([0.29, 0.67, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_time", style="selection_coefficient", ax=ins, linewidth=2, legend=False, color = color)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
ax.grid(True)
ax.set(xlabel='α', ylabel='fixation time')


    
fecundity_constant_df = deepcopy(fecundity_constant_df_adapted_alpha)
colors = "blue"
color = "blue"
linewidth = 2

ax = axs[i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)
    sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)


#ins = axs[i].inset_axes([0.29, 0.67, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_time", style="selection_coefficient", ax=ins, linewidth=2, legend=False, color = color)
ins.set_yscale("log")
ins.set(xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.patch.set_linewidth(2)
ins.tick_params(bottom=True, top=False, left=True, right=True)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
ax.grid(True)
ax.set(xlabel="αₐ", ylabel='fixation time')
    

legend_pos=-0.25
ncol=3
ax=axs[1]
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol) #labels=["s=0","s=0.01","s=0.1"]
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            

plt.tight_layout()
#plt.savefig("./figures/figure_5.pdf", dpi=500)
#plt.savefig("./figures/time_fixation_population_constant_selection_constant_diff-model.pdf", dpi=500)
# Out:
# /tmp/ipykernel_997723/24979726.py:43: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
# /tmp/ipykernel_997723/24979726.py:45: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("a) fecundity selection (N=" + str(population_size) + ")", loc="left")
# /tmp/ipykernel_997723/24979726.py:48: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
# /tmp/ipykernel_997723/24979726.py:59: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
# /tmp/ipykernel_997723/24979726.py:61: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient",
# /tmp/ipykernel_997723/24979726.py:64: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3), sharey=False)
alpha = np.linspace(1.1, 2, 10)
s = 0.01
pfix = alpha**(1/(alpha-1)) * s** (1/(alpha-1))
sns.lineplot(x=alpha, y=pfix, color="black", label="s=0.01", ax=ax)
s = 0.1
pfix = alpha**(1/(alpha-1)) * s** (1/(alpha-1))
sns.lineplot(x=alpha, y=pfix, color="blue", label="s=0.1", ax=ax)
ax.set(xlabel='α', ylabel='fixation probability')
ax.grid(True)

plt.ylim(0, 0.25)
# Out:
# (0.0, 0.25)

# %%
files = os.listdir(path)
files = [path + file for file in files if "probability" in file and "adapted" not in file]
files
# Out:
# []

# %%
from copy import deepcopy
fig, axs = plt.subplots(1, 2, figsize=(18, 6), sharey=False)
    

files = os.listdir(path)
files = [path + file for file in files if "probability" in file and "adapted" not in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
fecundity_constant_df["adapted_alpha"] = False
fecundity_constant_df_non_adapted_alpha = deepcopy(fecundity_constant_df)


files = os.listdir(path)
files = [path + file for file in files if "adapted" in file and "probability" in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()

fecundity_constant_df_adapted_alpha = deepcopy(fecundity_constant_df)
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist()     

    
i = 0
population_size = 1000
fecundity_constant_df = deepcopy(fecundity_constant_df_non_adapted_alpha)
colors = "black"
color = "black"
linewidth = 2
ax = axs[i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]

sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("a) fecundity selection (N=" + str(population_size) + ")", loc="left")

ins = axs[i].inset_axes([0.65, 0.3, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
             palette=colors, linewidth=linewidth, legend=False,  color = color)

    
    
    
fecundity_constant_df = deepcopy(fecundity_constant_df_adapted_alpha)
colors = "blue"
color = "blue"
linewidth = 2
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=True,  color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient",
                ax=ax, palette=colors, s=40, color = color, legend=False).set_title("a) fecundity selection (N=" + str(population_size) + ")", loc="left")
#ins = axs[i].inset_axes([0.65, 0.25, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
ins.set_yscale("log")
ins.set(ylim=(0.00001, 1), xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.tick_params(bottom=True, top=False, left=True, right=True)
ins.patch.set_linewidth(2)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.grid(True)
ax.patch.set_linewidth(2)
ax.set(xlabel='αₐ', ylabel='fixation probability')
    
    
legend_pos=-0.25    
ncol=3
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            
        
        

        
# fixation times
files = os.listdir(path)
files = [path + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and "adapted" not in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

fecundity_constant_df["adapted_alpha"] = False
fecundity_constant_df_non_adapted_alpha = deepcopy(fecundity_constant_df)

files = os.listdir(path)
files = [path + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "adapted" in file and "time" in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

fecundity_constant_df_adapted_alpha = deepcopy(fecundity_constant_df)        
        


i = 1
population_size = 1000
fecundity_constant_df = deepcopy(fecundity_constant_df_non_adapted_alpha)

colors = ["#03045e", "#0077b6", "#00b4d8"]
colors = "black"
color = "black"
linewidth = 2

ax = axs[i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("b) fecundity selection (N=" + str(population_size) + ")", loc="left")

ins = axs[i].inset_axes([0.29, 0.67, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_time", style="selection_coefficient", ax=ins, linewidth=2, legend=False, color = color)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
ax.grid(True)
ax.set(xlabel='α', ylabel='fixation time')


    
fecundity_constant_df = deepcopy(fecundity_constant_df_adapted_alpha)
colors = "blue"
color = "blue"
linewidth = 2

ax = axs[i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)
    sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)


#ins = axs[i].inset_axes([0.29, 0.67, 0.25, 0.25])
sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_time", style="selection_coefficient", ax=ins, linewidth=2, legend=False, color = color)
ins.set_yscale("log")
ins.set(xlabel='', ylabel='')
ins.patch.set_edgecolor('black')  
ins.patch.set_linewidth(2)
ins.tick_params(bottom=True, top=False, left=True, right=True)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth(2) 
ax.grid(True)
ax.set(xlabel="αₐ", ylabel='fixation time')
    

legend_pos=-0.25
ncol=3
ax=axs[1]
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol) #labels=["s=0","s=0.01","s=0.1"]
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            

plt.tight_layout()
#plt.savefig("./figures/figure_5.pdf", dpi=500)

#plt.savefig("./figures/time_fixation_population_constant_selection_constant_diff-model.pdf", dpi=500)
# Out:
# /tmp/ipykernel_997723/2795965350.py:44: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
# /tmp/ipykernel_997723/2795965350.py:46: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("a) fecundity selection (N=" + str(population_size) + ")", loc="left")
# /tmp/ipykernel_997723/2795965350.py:49: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
# /tmp/ipykernel_997723/2795965350.py:60: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
# /tmp/ipykernel_997723/2795965350.py:62: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient",
# /tmp/ipykernel_997723/2795965350.py:65: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=fecundity_constant_population_size,x="parameter", y="fixation_probability", style="selection_coefficient", ax=ins,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 96
#      94 # filter the times
#      95 df_time = [pd.read_csv(file) for file in files if "time" in file and "adapted" not in file]
# ---> 96 df_time = pd.concat(df_time).reset_index()
#      98 df = df_time[df_time["population_size_model"] == "constant"]
#      99 viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
#
# File ~/CanningsSimulator/.venv/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/CanningsSimulator/.venv/lib/python3.12/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/CanningsSimulator/.venv/lib/python3.12/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %% [markdown]
# ## Figure 6

# %%
sns.set(font_scale = 1.3, style="whitegrid")
sns.set_style("whitegrid", {'axes.edgecolor' : '.0001'})

population_sizes = [500,1000,5000]

fig, axs = plt.subplots(2, 2, figsize=(18, 12), sharey=True)


files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and \
           "shifted_0.0" in file and \
           "period" in file and \
           "0.006283" in file 
          ]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "probability" in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and "period" not in file and "constant_selection_0.0_" in file and "adapted" not in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()

viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])


colors = "black"
color = "blue"
linewidth = 2
i = 0

population_size = 1000
ax = axs[0][0]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
                palette=colors, s=40, legend=False,  color = color).set_title("a) slow fluctuating viability selection (N=" + str(population_size) + ")",  loc="left")
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
#ax.grid(True)
ax.patch.set_linewidth('2')
ax.set(xlabel='', ylabel='fixation probability')


ax = axs[1][0]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("c) slow fluctuating fecundity selection (N=" + str(population_size) + ")", loc="left")
ax = sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, linewidth=linewidth, legend=True, color = color)
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.grid(True)
ax.patch.set_linewidth('2')
ax.set(xlabel='α', ylabel='fixation probability')
legend_pos=-0.25    
ncol=3
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])#labels=["s=0","s=0.01","s=0.1"]
for line in leg.get_lines():
    line.set_linewidth(2.1) 

    
    
    
    
    
    

    
    
    
    
    
    
    
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and \
           "shifted_3.1" in file and \
           "period" in file and \
           "0.006283" in file 
          ]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "probability" in file and "adapted" not in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and "period" not in file and "constant_selection_0.0_" in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()
viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])
    
colors = "black"
color = "#7cb0c7"
linewidth = 2
i = 0
ax=axs[0][0]
population_size = 1000
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
                palette=colors, s=40, legend=False,  color = color)#.set_title(pos_to_char(i) + ") viability selection (N=" + str(population_size) + ")",  loc="left")
ax.set(xlabel='α', ylabel='fixation probability')
ax = axs[1][0]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
if i == 1:
    ax = sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, linewidth=linewidth, legend=True, color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color)#.set_title(pos_to_char(i+3) + ") fecundity selection (N=" + str(population_size) + ")", loc="left")
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=True,  color = color)
legend_pos=-0.25    
ncol=3
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
for line in leg.get_lines():
    line.set_linewidth(2.1) 
    
    
    
    
    
    
    
    
    
    
    
# fast

files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and \
           "shifted_0.0" in file and \
           "period" in file and \
           "0.06283" in file 
          ]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

#files = os.listdir("./simulations_old_floor/")
#files = ["./simulations_old_floor/" + file for file in files if "probability" in file]

files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "probability" in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and "period" not in file and "constant_selection_0.0_" in file and "shifted_0.0" in file and "adapted_Schweinsberg" not in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()
#selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])

colors = "black"
color = "#cb0000"
linewidth = 2
i = 1
population_sizes = 1000
ax = axs[0][i]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
                palette=colors, s=40, legend=False,  color = color)#.set_title(pos_to_char(i) + ") viability selection (N=" + str(population_size) + ")",  loc="left")

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
#ax.grid(True)
ax.patch.set_linewidth('2')
ax.set(xlabel='α', ylabel='fixation probability')

ax = axs[1][i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, palette=colors, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, color=color, linewidth=linewidth, legend=False)
if i == 1:
    ax = sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, linewidth=linewidth, legend=True, color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("d) fecundity selection (N=" + str(population_size) + ")", loc="left")
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.grid(True)
ax.patch.set_linewidth('2')
ax.set(xlabel='α', ylabel='fixation probability')
legend_pos=-0.25    
ncol=3
#ax=axs[1][1]
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            

        
        
        
        
        
        
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and \
           "shifted_3.1" in file and \
           "period" in file and \
           "0.06283" in file 
          ]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "probability" in file and "adapted" not in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "probability" in file and "period" not in file and "constant_selection_0.0_" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()
viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])
    
colors = "black"
color = "#ff5b5b"
linewidth = 2
i = 0
population_size = 1000
ax = axs[0][1]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
                palette=colors, s=40, legend=False,  color = color).set_title("b) fast fluctuating viability selection (N=" + str(population_size) + ")",  loc="left")
#ax.grid(True)
ax.patch.set_linewidth('2')
ax.set(xlabel='', ylabel='fixation probability')
ax = axs[1][1]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax,
             palette=colors, linewidth=linewidth, legend=False,  color = color)

if i == 0:
    ax = sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, linewidth=linewidth, legend=True, color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_probability", style="selection_coefficient", ax=ax, palette=colors, s=40, legend=False, color = color).set_title("d) fast fluctuating fecundity selection (N=" + str(population_size) + ")", loc="left")

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.grid(True)
ax.patch.set_linewidth('2')
ax.set(xlabel='α', ylabel='fixation probability')

legend_pos=-0.25    
ncol=3
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])#labels=["s=0","s=0.01","s=0.1"]
for line in leg.get_lines():
    line.set_linewidth(2.1)                       
               
        
        
plt.tight_layout()
plt.savefig("./figures/figure_6.pdf", dpi=500)

# %%
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and \
           "shifted_0.0" in file and \
           "period" in file and \
           "0.006283" in file 
          ]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "time" in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and "period" not in file and "constant_selection_0.0_" in file and "adapted" not in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()
viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])


sns.set_style("whitegrid", {'axes.edgecolor' : '.0001'})

fig, axs = plt.subplots(2, 2, figsize=(18, 12), sharey=True)

colors = "black"
color = "blue"
linewidth = 2

i = 0
population_size = 1000
ax = axs[0][i]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("a) slow fluctuating viability selection (N=" + str(population_size) + ")",  loc="left")

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = viability_constant_population_size[viability_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='', ylabel='fixation time')

ax = axs[1][i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

if i == 1:
    sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)

sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("c) slow fluctuating fecundity selection (N=" + str(population_size) + ")", loc="left")

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='α', ylabel='fixation time')
    

    
    
    
    
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and \
           "shifted_3.1" in file and \
           "period" in file and \
           "0.006283" in file 
          ]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "time" in file and "adapted" not in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and "period" not in file and "constant_selection_0.0_" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()

viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])   
    
    



colors = "black"
color = "#7cb0c7"
linewidth = 2

i = 0
population_size = 1000
ax = axs[0][i]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("a) slow fluctuating viability selection (N=" + str(population_size) + ")",  loc="left")

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = viability_constant_population_size[viability_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='', ylabel='fixation time')


ax = axs[1][i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)
sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("c) slow fluctuating fecundity selection (N=" + str(population_size) + ")", loc="left")
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='α', ylabel='fixation time')

legend_pos=-0.25    
ncol=3
#ax=axs[1][1]
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            

    
    

    
    
    
    
    
    
# fast
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and \
           "shifted_0.0" in file and \
           "period" in file and \
           "0.06283" in file 
          ]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "time" in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and "period" not in file and "constant_selection_0.0_" in file and "shifted_0.0" in file and "adapted_Schweinsberg" not in file]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()
viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])
    
    



colors = "black"
color = "#cb0000"
linewidth = 2

i = 1
population_size = 1000
ax = axs[0][i]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color)#.set_title(pos_to_char(i) + ") viability selection (N=" + str(population_size) + ")",  loc="left")

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = viability_constant_population_size[viability_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='', ylabel='fixation time')

ax = axs[1][i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

if i == 1:
    sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)

sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color)#.set_title(pos_to_char(i+3) + ") fecundity selection (N=" + str(population_size) + ")", loc="left")
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='α', ylabel='fixation time')






files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files]
# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and \
           "shifted_3.1" in file and \
           "period" in file and \
           "0.06283" in file 
          ]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df = df[df["selection_type"] == "viability_sinus"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_sinus"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 

files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "time" in file and "adapted" not in file]

# filter the times
df_time = [pd.read_csv(file) for file in files if "time" in file and "period" not in file and "constant_selection_0.0_" in file]
df_time = pd.concat(df_time).reset_index()
df = df_time[df_time["population_size_model"] == "constant"]

viability_constant_df_neutral = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df_neutral = df[df["selection_type"] == "fecundity_constant"].reset_index()
viability_constant_df = pd.concat([viability_constant_df, viability_constant_df_neutral])
fecundity_constant_df = pd.concat([fecundity_constant_df, fecundity_constant_df_neutral])



sns.set_style("whitegrid", {'axes.edgecolor' : '.0001'})


colors = "black"
color = "#ff5b5b"
linewidth = 2

i = 1
population_size = 1000
ax = axs[0][i]
viability_constant_population_size = df = viability_constant_df[viability_constant_df["population_size"] == population_size]
sns.lineplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)
sns.scatterplot(data=viability_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("b) fast fluctuating viability selection (N=" + str(population_size) + ")",  loc="left")

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = viability_constant_population_size[viability_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='', ylabel='fixation time')


ax = axs[1][i]
fecundity_constant_population_size = df = fecundity_constant_df[fecundity_constant_df["population_size"] == population_size]
sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=False, color = color)

for j, selection_coefficient in enumerate(selection_coefficients):
    std_frame = fecundity_constant_population_size[fecundity_constant_population_size["selection_coefficient"] == selection_coefficient]
    std_frame = std_frame.sort_values(by="parameter")
    ax.fill_between(std_frame["parameter"], y1=std_frame["fixation_time"] - std_frame["standard_deviation"], y2=std_frame["fixation_time"] + std_frame["standard_deviation"], alpha=.15, color = color)

if i == 1:
    sns.lineplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, linewidth=2, legend=True, color = color)

sns.scatterplot(data=fecundity_constant_population_size, x="parameter", y="fixation_time", style="selection_coefficient", ax=ax, s=40, legend=False, color = color).set_title("d) fast fluctuating fecundity selection (N=" + str(population_size) + ")", loc="left")
ax.tick_params(bottom=True, top=False, left=True, right=True)
ax.patch.set_edgecolor('black')  
ax.patch.set_linewidth('2') 
ax.grid(True)
ax.set(xlabel='α', ylabel='fixation time')
    

legend_pos=-0.25    
ncol=3
ax=axs[1][1]
box = ax.get_position()
h, l = ax.get_legend_handles_labels()
leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
for line in leg.get_lines():
    line.set_linewidth(2.1) 
            
    
plt.tight_layout()
plt.savefig("./figures/figure_6_times.pdf", dpi=500)

# %%
population_size = 500


# all simulation files for probability and no alpha adapted selection
files = os.listdir("../simulations/")
files = ["../simulations/" + file for file in files if "probability" in file and "adapted" not in file and "Poisson" in file]

# filter the probabilities
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

# filter for constant
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
df = pd.concat([viability_constant_df, fecundity_constant_df])

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 4), sharey=True)
sns.scatterplot(data=viability_constant_df, x="population_size", y="fixation_probability", hue="selection_coefficient", ax=axs[0])
sns.scatterplot(data=fecundity_constant_df, x="population_size", y="fixation_probability", hue="selection_coefficient", ax=axs[1])


legend_pos=-0.25    
ncol=3
for i in range(2):
    ax=axs[i]
    box = ax.get_position()
    h, l = ax.get_legend_handles_labels()
    leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
    for line in leg.get_lines():
        line.set_linewidth(2.1)

# %%
population_size = 500


# all simulation files for probability and no alpha adapted selection
files = os.listdir("../poisson-old/")
files = ["../poisson-old/" + file for file in files if "probability" in file and "adapted" not in file and "Poisson" in file and "1.2" in file and "500000" in file]

# filter the probabilities
df_time = [pd.read_csv(file) for file in files if "probability" in file]
df_time = pd.concat(df_time).reset_index()

# filter for constant
df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 
df = pd.concat([viability_constant_df, fecundity_constant_df])

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 4), sharey=True)
sns.scatterplot(data=viability_constant_df, x="population_size", y="fixation_probability", hue="selection_coefficient", ax=axs[0])
sns.scatterplot(data=fecundity_constant_df, x="population_size", y="fixation_probability", hue="selection_coefficient", ax=axs[1])


legend_pos=-0.25    
ncol=3
for i in range(2):
    ax=axs[i]
    box = ax.get_position()
    h, l = ax.get_legend_handles_labels()
    leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
    for line in leg.get_lines():
        line.set_linewidth(2.1)

# %%
prob = df_time[["fixation_probability", "selection_coefficient", "population_size", "selection_type"]].sort_values(by=["selection_type","population_size","selection_coefficient"])["fixation_probability"]

# %%
np.round(prob, 5).tolist()
# Out:
# [0.00197,
#  0.00685,
#  0.06851,
#  0.00097,
#  0.00689,
#  0.06826,
#  0.00023,
#  0.00674,
#  0.06871,
#  0.00201,
#  0.00736,
#  0.06169,
#  0.00095,
#  0.00705,
#  0.06274,
#  0.0002,
#  0.00702,
#  0.06276]

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 4), sharey=True)

## fixation times

files = os.listdir("../poisson-old/")
files = ["../poisson-old/" + file for file in files if "time" in file and "adapted" not in file and "Poisson" in file and "1.2" in file]

# filter the times
df_time = [pd.read_csv(file) for file in files]
df_time = pd.concat(df_time).reset_index()

df = df_time[df_time["population_size_model"] == "constant"]
viability_constant_df = df[df["selection_type"] == "viability_constant"].reset_index()
fecundity_constant_df = df[df["selection_type"] == "fecundity_constant"].reset_index()
selection_coefficients = viability_constant_df.selection_coefficient.unique().tolist() 


sns.scatterplot(data=viability_constant_df, x="population_size", y="fixation_time", hue="selection_coefficient", ax=axs[0])
sns.scatterplot(data=fecundity_constant_df, x="population_size", y="fixation_time", hue="selection_coefficient", ax=axs[1])


legend_pos=-0.25    
ncol=3
for i in range(2):
    ax=axs[i]
    box = ax.get_position()
    h, l = ax.get_legend_handles_labels()
    leg = ax.legend(handles=h, loc='upper center',bbox_to_anchor=(0.5, legend_pos), fancybox=True, shadow=False, ncol=ncol, labels=["s=0","s=0.01","s=0.1"])
    for line in leg.get_lines():
        line.set_linewidth(2.1)

# %%
times = df_time[["fixation_time", "selection_coefficient", "population_size", "selection_type"]].sort_values(by=["selection_type","population_size","selection_coefficient"])["fixation_time"]

# %%
np.round(times, 2).tolist()
# Out:
# [999.15,
#  587.38,
#  108.64,
#  2000.45,
#  740.88,
#  123.08,
#  9976.43,
#  1070.92,
#  156.69,
#  995.14,
#  862.7,
#  239.36,
#  2005.19,
#  1328.78,
#  280.35,
#  9973.58,
#  2303.67,
#  373.39]

# %%
df_time
# Out:
#     index  fixation_time  parameter  population_size population_size_model  \
# 0       0     862.703941        1.2              500              constant
# 1       0     995.140028        1.2              500              constant
# 2       0     740.880976        1.2             1000              constant
# 3       0     999.146229        1.2              500              constant
# 4       0    2303.666333        1.2             5000              constant
# 5       0     239.355871        1.2              500              constant
# 6       0    9973.582917        1.2             5000              constant
# 7       0    2000.452490        1.2             1000              constant
# 8       0     108.635127        1.2              500              constant
# 9       0     587.383877        1.2              500              constant
# 10      0     156.691938        1.2             5000              constant
# 11      0     123.083017        1.2             1000              constant
# 12      0    1070.917984        1.2             5000              constant
# 13      0    2005.185637        1.2             1000              constant
# 14      0     280.351670        1.2             1000              constant
# 15      0    9976.429486        1.2             5000              constant
# 16      0     373.394479        1.2             5000              constant
# 17      0    1328.781156        1.2             1000              constant
#
#     selection_coefficient  selection_period      selection_type  \
# 0                    0.01           0.06283  viability_constant
# 1                    0.00           0.06283  viability_constant
# 2                    0.01           0.06283  fecundity_constant
# 3                    0.00           0.06283  fecundity_constant
# 4                    0.01           0.06283  viability_constant
# 5                    0.10           0.06283  viability_constant
# 6                    0.00           0.06283  viability_constant
# 7                    0.00           0.06283  fecundity_constant
# 8                    0.10           0.06283  fecundity_constant
# 9                    0.01           0.06283  fecundity_constant
# 10                   0.10           0.06283  fecundity_constant
# 11                   0.10           0.06283  fecundity_constant
# 12                   0.01           0.06283  fecundity_constant
# 13                   0.00           0.06283  viability_constant
# 14                   0.10           0.06283  viability_constant
# 15                   0.00           0.06283  fecundity_constant
# 16                   0.10           0.06283  viability_constant
# 17                   0.01           0.06283  viability_constant
#
#     standard_deviation
# 0           430.490824
# 1           524.938980
# 2           219.881892
# 3           536.116032
# 4           546.978023
# 5            59.260178
# 6          5364.346932
# 7          1102.821992
# 8            20.805673
# 9           227.721129
# 10           19.674754
# 11           20.108392
# 12          198.583104
# 13         1117.393251
# 14           55.912357
# 15         5400.522645
# 16           53.802032
# 17          556.159605
